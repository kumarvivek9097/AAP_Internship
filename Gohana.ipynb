# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/home/vivek/Documents/Internship/AAP_Data_Analytics/Task 5/GOHANA - Sheet1.csv')
data.drop(['TOTAL VOTES POLLED'],axis=1,inplace=True)
data.head()
#df=data.groupby(['YEAR'])
#data.head()
#df.head()
#df.sort_values(by=['VOTES PERCENTAGE'], ascending=False)
# Out:
#    YEAR  PARTY  VOTES PERCENTAGE
# 0  2014   INLD         32.583454
# 1  2014    BSP          1.444549
# 2  2014    INC         35.339367
# 3  2014  HJCBL          1.039870
# 4  2014    BJP         24.216682

# %%
df=data.loc[(data['YEAR']==1996)]
df1=df.sort_values(by=['VOTES PERCENTAGE'], ascending=False)
df2=df1[['VOTES PERCENTAGE']]
df2 = df2.reset_index(drop=True)
df2
# Out:
#    VOTES PERCENTAGE
# 0             28.88
# 1             27.77
# 2             22.54
# 3             12.22
# 4              0.28
# 5              0.17

# %%
#for i in range(0,15):
#    df3=df2.iloc[i]-df2.iloc[i+1]
#    print df3

# %%
#dff=data.groupby(['YEAR'])
#dff.head()
#x=dff['YEAR']
#y=dff['VOTES PERCENTAGE']
#plt.bar(x,y)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax2 = ax.twinx()
width = 0.4
dff=data.groupby(['YEAR'])
dff6=data.loc[(data['PARTY']=='BJP')]
dff1=data.loc[(data['PARTY']=='INC')]
dff2=data.loc[(data['PARTY']=='INLD')]
dff3=data.loc[(data['PARTY']=='BSP')]
dff4=data.loc[(data['PARTY']=='IND')]
dff5=data.loc[(data['PARTY']=='HVP')]

X=df['YEAR']
Y=df['VOTES PERCENTAGE']

dff.plot(kind='bar', color='red', ax=ax, width=width, position=1)
dff1.plot(kind='bar', color='green', ax=ax, width=width, position=0)

#plt.figure(figsize=(20,10))
#plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Votes Percentage',fontsize=20)
#plt.title('BJP (Gohana)',fontsize=20)
#plt.bar(X,Y)

# %%
df=data.loc[(data['YEAR']==2014)]
df1=df.sort_values(by=['VOTES PERCENTAGE'], ascending=False).head(6)
x=df1['PARTY']
y=df1['VOTES PERCENTAGE']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Party',fontsize=20)
plt.ylabel('Votes Percentage',fontsize=20)
plt.title('2014 (Gohana)',fontsize=20)
plt.tick_params(labelsize=15)
plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
print(x)
print(y)
print(100-y.sum())
# Out:
# 2      INC
# 0     INLD
# 4      BJP
# 5     HaLP
# 1      BSP
# 14     IND
# Name: PARTY, dtype: object
# 2     35.339367
# 0     32.583454
# 4     24.216682
# 5      1.894476
# 1      1.444549
# 14     1.403569
# Name: VOTES PERCENTAGE, dtype: float64
# 3.1179031809999884

# %%
#figure = plt.figure()
labels=['INC','INLD','BJP','HaLP','BSP','IND','OTHERS']
size=[35.339367,
32.583454,
24.216682,
1.894476,
1.444549,
1.403569,3.1179031809999884]
plt.figure(figsize=(20,10))
figure,ax1 = plt.subplots()
colors = ['green', 'blue', 'orange', 'red','grey','violet','pink']
result=ax1.pie(size,labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90,colors=colors)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.legend(result[0], size,  bbox_to_anchor=(0.00, 1),fontsize=15)
plt.title('2014 (Gohana)',fontsize=20)
figure.subplots_adjust(top=0.95)
plt.show()

# %%
df=data.loc[(data['YEAR']==2009)]
df2=df.sort_values(by=['VOTES PERCENTAGE'], ascending=False).head(6)
x1=df2['PARTY']
y1=df2['VOTES PERCENTAGE']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Party',fontsize=20)
plt.ylabel('Votes Percentage',fontsize=20)
plt.title('2009 (Gohana)',fontsize=20)
plt.tick_params(labelsize=15)
plt.bar(x1,y1)
# Out:
# <BarContainer object of 6 artists>

# %%
print(x1)
print(y1)
print(100-y1.sum())
# Out:
# 18      INC
# 17     INLD
# 24      IND
# 20      BJP
# 21    HJCBL
# 19      BSP
# Name: PARTY, dtype: object
# 18    42.475327
# 17    26.790943
# 24    11.828359
# 20     8.717028
# 21     4.695916
# 19     2.411221
# Name: VOTES PERCENTAGE, dtype: float64
# 3.0812054890000127

# %%
#figure = plt.figure()
labels=['INC','INLD','IND','BJP','HJC(BL)','BSP','OTHERS']
size=[42.475327,
26.790943,
11.828359,
8.717028,
4.695916,
2.411221,3.0812054890000127]
plt.figure(figsize=(20,10))
figure,ax1 = plt.subplots()
colors = ['green', 'blue','violet', 'orange', 'red','grey','pink']
result=ax1.pie(size,labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90,colors=colors)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.legend(result[0], size,  bbox_to_anchor=(0.00, 1),fontsize=15)
plt.title('2009 (Gohana)',fontsize=20)
figure.subplots_adjust(top=0.95)
plt.show()

# %%
df=data.loc[(data['YEAR']==2005)]
df3=df.sort_values(by=['VOTES PERCENTAGE'], ascending=False).head(6)
x2=df3['PARTY']
y2=df3['VOTES PERCENTAGE']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Party',fontsize=20)
plt.ylabel('Votes Percentage',fontsize=20)
plt.title('2005 (Gohana)',fontsize=20)
plt.tick_params(labelsize=15)
plt.bar(x2,y2)
# Out:
# <BarContainer object of 6 artists>

# %%
print(x2)
print(y2)
print(100-y2.sum())
# Out:
# 32      INLD
# 33     JD(S)
# 30       BSP
# 31       INC
# 34    JJJKMC
# 41       IND
# Name: PARTY, dtype: object
# 32    46.203096
# 33    31.459908
# 30    13.739921
# 31     5.545472
# 34     0.599540
# 41     0.596240
# Name: VOTES PERCENTAGE, dtype: float64
# 1.8558243457000003

# %%
#figure = plt.figure()
labels=['INLD','JD(S)','BSP','INC','JJJKMC','IND','OTHERS']
size=[46.203096,
31.459908,
13.739921,
5.545472,
0.599540,0.596240,1.8558243457000003]
plt.figure(figsize=(20,10))
figure,ax1 = plt.subplots()
colors = ['blue','red','grey','green','black','violet','pink']
result=ax1.pie(size,labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90,colors=colors)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.legend(result[0], size,  bbox_to_anchor=(0.00, 1),fontsize=15)
plt.title('2005 (Gohana)',fontsize=20)
figure.subplots_adjust(top=0.95)
plt.show()

# %%
df=data.loc[(data['YEAR']==2000)]
df1=df.sort_values(by=['VOTES PERCENTAGE'], ascending=False).head(8)
x=df1['PARTY']
y=df1['VOTES PERCENTAGE']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Party',fontsize=20)
plt.ylabel('Votes Percentage',fontsize=20)
plt.title('2000 (Gohana)',fontsize=20)
plt.tick_params(labelsize=15)
plt.bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
df=data.loc[(data['YEAR']==1996)]
df1=df.sort_values(by=['VOTES PERCENTAGE'], ascending=False).head(8)
x=df1['PARTY']
y=df1['VOTES PERCENTAGE']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Party',fontsize=20)
plt.ylabel('Votes Percentage',fontsize=20)
plt.title('1996 (Gohana)',fontsize=20)
plt.tick_params(labelsize=15)
plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
df=data.loc[(data['PARTY']=='BJP')]
X=df['YEAR']
Y=df['VOTES PERCENTAGE']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Votes Percentage',fontsize=20)
plt.title('BJP (Gohana)',fontsize=20)
plt.bar(X,Y)
# Out:
# <BarContainer object of 3 artists>

# %%
df1=data.loc[(data['PARTY']=='INC')]
X=df1['YEAR']
Y=df1['VOTES PERCENTAGE']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Votes Percentage',fontsize=20)
plt.title('INC (Gohana)',fontsize=20)
plt.bar(X,Y)
# Out:
# <BarContainer object of 5 artists>

# %%
df2=data.loc[(data['PARTY']=='INLD')]
X=df2['YEAR']
Y=df2['VOTES PERCENTAGE']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Votes Percentage',fontsize=20)
plt.title('INLD (Gohana)',fontsize=20)
plt.bar(X,Y)
# Out:
# <BarContainer object of 4 artists>

# %%
df3=data.loc[(data['PARTY']=='BSP')]
X=df3['YEAR']
Y=df3['VOTES PERCENTAGE']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Votes Percentage',fontsize=20)
plt.title('BSP (Gohana)',fontsize=20)
plt.bar(X,Y)
# Out:
# <BarContainer object of 4 artists>

# %%
df4=data.loc[(data['PARTY']=='SP')]
X=df4['YEAR']
Y=df4['VOTES PERCENTAGE']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Votes Percentage',fontsize=20)
plt.title('SP (Gohana)',fontsize=20)
plt.bar(X,Y)
# Out:
# <BarContainer object of 2 artists>

# %%
df5=data.loc[(data['PARTY']=='IND')]
X=df5['YEAR']
Y=df5['VOTES PERCENTAGE']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Votes Percentage',fontsize=20)
plt.title('IND (Gohana)',fontsize=20)
plt.bar(X,Y)
# Out:
# <BarContainer object of 26 artists>

# %%
dff=data.loc[(data['PARTY']=='BJP')]
print(dff.max())
print(dff.min())
# Out:
# YEAR                   2014
# PARTY                   BJP
# VOTES PERCENTAGE    24.2167
# dtype: object
# YEAR                    2005
# PARTY                    BJP
# VOTES PERCENTAGE    0.353124
# dtype: object

# %%
dff=data.loc[(data['PARTY']=='INC')]
print(dff.max())
print(dff.min())
# Out:
# YEAR                   2014
# PARTY                   INC
# VOTES PERCENTAGE    42.4753
# dtype: object
# YEAR                   1996
# PARTY                   INC
# VOTES PERCENTAGE    5.54547
# dtype: object

# %%
dff=data.loc[(data['PARTY']=='INLD')]
print(dff.max())
print(dff.min())
# Out:
# YEAR                   2014
# PARTY                  INLD
# VOTES PERCENTAGE    46.2031
# dtype: object
# YEAR                   2000
# PARTY                  INLD
# VOTES PERCENTAGE    26.7909
# dtype: object

# %%
dff=data.loc[(data['PARTY']=='SAP')]
print(dff.max())
print(dff.min())
# Out:
# YEAR                 1996
# PARTY                 SAP
# VOTES PERCENTAGE    27.77
# dtype: object
# YEAR                 1996
# PARTY                 SAP
# VOTES PERCENTAGE    27.77
# dtype: object

# %%
dff=data.loc[(data['PARTY']=='HVP')]
print(dff.max())
print(dff.min())
# Out:
# YEAR                 2000
# PARTY                 HVP
# VOTES PERCENTAGE    28.88
# dtype: object
# YEAR                 1996
# PARTY                 HVP
# VOTES PERCENTAGE    17.23
# dtype: object

# %%
dff=data.loc[(data['PARTY']=='BSP')]
print(dff.max())
print(dff.min())
# Out:
# YEAR                   2014
# PARTY                   BSP
# VOTES PERCENTAGE    13.7399
# dtype: object
# YEAR                   2000
# PARTY                   BSP
# VOTES PERCENTAGE    1.44455
# dtype: object
