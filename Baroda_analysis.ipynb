# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('/home/vivek/Documents/Internship/AAP_Data_Analytics/Task 6/Part 2/baroda/2005.xlsx')
data.tail()
# Out:
#      PollingStationNo.  BSP  BJP  INC  INLD  ES  IND  IND.1  IND.2  \
# 118                119    9   21  405   219   3   96      4      4
# 119                120   11   64  316   273   8  252      4      5
# 120                121    7   26  430   373   2   69      6      5
# 121                122    6   85  165   273   1   76      0      2
# 122                123    2   36  178   148   3  136      4      1
#
#      Total Votes
# 118          761
# 119          933
# 120          918
# 121          608
# 122          508

# %%
df=data['BSP']
df.head()
# Out:
# 0     1
# 1    10
# 2     9
# 3     3
# 4     7
# Name: BSP, dtype: int64

# %%
df.std(axis=0)
df.mean()
# Out:
# 7.40650406504065

# %%
df1=data['BJP']
df1.std(axis=0)
df1.mean()
# Out:
# 102.26829268292683

# %%
df2=data['INC']
df2.std(axis=0)
df2.mean()
# Out:
# 188.3008130081301

# %%
df3=data['INLD']
df3.std(axis=0)
df3.mean()
# Out:
# 214.58536585365854

# %%
df4=data['ES']
df4.std(axis=0)
df4.mean()
# Out:
# 12.365853658536585

# %%
df5=data['IND']
df5.std(axis=0)
df5.mean()
# Out:
# 84.13821138211382

# %%
df[df>7.40650406504065].count()
# Out:
# 36

# %%
df1[df1>102.26829268292683].count()
# Out:
# 40

# %%
df2[df2>188.3008130081301].count()
# Out:
# 51

# %%
df3[df3>214.58536585365854].count()
# Out:
# 57

# %%
df4[df4>12.365853658536585].count()
# Out:
# 14

# %%
labels = 'Above Mean', 'Below Mean'
fracs = [36, 87]
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('BSP(2005)')
# Out:
# Text(0.5,1,'BSP(2005)')

# %%
labels = 'Above Mean', 'Below Mean'
fracs = [40, 83]
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('BJP(2005)')
# Out:
# Text(0.5,1,'BJP(2005)')

# %%
labels = 'Above Mean', 'Below Mean'
fracs = [51, 72]
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('INC(2005)')
# Out:
# Text(0.5,1,'INC(2005)')

# %%
labels = 'Above Mean', 'Below Mean'
fracs = [57, 66]
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('INLD(2005)')
# Out:
# Text(0.5,1,'INLD(2005)')

# %%
labels = 'Above Mean', 'Below Mean'
fracs = [14, 109]
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('ES(2005)')
# Out:
# Text(0.5,1,'ES(2005)')

# %%
data1=pd.read_excel('/home/vivek/Documents/Internship/AAP_Data_Analytics/Task 6/Part 2/baroda/2009.xlsx')
data1.tail()
# Out:
#     Sr. No.  INLD  BSP  NCP  BJP  INC  HJCBL  CPI  SBP  JD(S)  LJSP  USP  HJD  \
# 163     163    45    8    0    0   33      0    0    0      0     0    0    0
# 164     164   144    1    1   13  553      2    2    0      0     1    3    1
# 165     165   123    0    1    4  473     23    0    1      2     0    4    0
# 166     166    45   10    3    0   77      0    0    1      0     0    1    0
# 167     167    84    2    1    7  485      3    0    3      1     1    4    1
#
#      IND  IND.1  IND.2  Total Votes
# 163    0      0      0           86
# 164    0      2      0          723
# 165    0      0      2          633
# 166    0      0      1          138
# 167    1      0      2          595

# %%
dff=data1['INC']
dff.std(axis=0)
dff.mean(axis=0)
# Out:
# 334.5238095238095

# %%
dff1=data1['BJP']
dff1.std(axis=0)
dff1.mean(axis=0)
# Out:
# 7.023809523809524

# %%
dff2=data1['INLD']
dff2.std(axis=0)
dff2.mean(axis=0)
# Out:
# 183.7797619047619

# %%
dff3=data1['BSP']
dff3.std(axis=0)
dff3.mean(axis=0)
# Out:
# 14.69047619047619

# %%
dff4=data1['NCP']
dff4.std(axis=0)
dff4.mean(axis=0)
# Out:
# 3.1785714285714284

# %%
dff5=data1['CPI']
dff5.std(axis=0)
dff5.mean(axis=0)
# Out:
# 1.9107142857142858

# %%
dff[dff>334.5238095238095].count()
# Out:
# 88

# %%
dff1[dff1>7.023809523809524].count()
# Out:
# 60

# %%
dff2[dff2>183.7797619047619].count()
# Out:
# 75

# %%
dff3[dff3>14.69047619047619].count()
# Out:
# 38

# %%
dff4[dff4>3.1785714285714284].count()
# Out:
# 27

# %%
labels = 'Above Mean', 'Below Mean'
fracs = [88, 79]
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('INC(2009)')
# Out:
# Text(0.5,1,'INC(2009)')

# %%
labels = 'Above Mean', 'Below Mean'
fracs = [60, 107]
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('BJP(2009)')
# Out:
# Text(0.5,1,'BJP(2009)')

# %%
labels = 'Above Mean', 'Below Mean'
fracs = [75, 92]
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('INLD(2009)')
# Out:
# Text(0.5,1,'INLD(2009)')

# %%
labels = 'Above Mean', 'Below Mean'
fracs = [38, 129]
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('BSP(2009)')
# Out:
# Text(0.5,1,'BSP(2009)')

# %%
labels = 'Above Mean', 'Below Mean'
fracs = [27, 140]
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('NCP(2009)')
# Out:
# Text(0.5,1,'NCP(2009)')

# %%
data2=pd.read_excel('/home/vivek/Documents/Internship/AAP_Data_Analytics/Task 6/Part 2/baroda/2014.xlsx')
data2.tail()
# Out:
#      Sr. No.  INLD  BSP  BJP  INC  KAJP  HJCPV  HaLP  IND  IND   IND.1  IND.2  \
# 179      180    69    6    6   37     0      0     0    0     0      0      0
# 180      181   201    1  119  294     3      0     2    0     0      0      0
# 181      182   325    1   24  486     2      0     4    1     1      0      0
# 182      183    65    3   12   87     0      1     0    0     0      0      0
# 183      184   288    4   40  490     4      1     0    0     0      0      0
#
#      IND.3  IND.4  IND.5  IND.6  IND.7  IND.8  Total Votes
# 179      0      0      0      0      0      0          118
# 180      1      3      1      1      0      2          628
# 181      0      0      0      0      1      6          851
# 182      3      1      2      1      1      0          176
# 183      1      3      2      0      6     13          852

# %%
dfff=data2['INC']
dfff.std(axis=0)
dfff.mean(axis=0)
# Out:
# 274.33152173913044

# %%
dfff1=data2['INLD']
dfff1.std(axis=0)
dfff1.mean(axis=0)
# Out:
# 246.1413043478261

# %%
dfff2=data2['BJP']
dfff2.std(axis=0)
dfff2.mean(axis=0)
# Out:
# 47.25

# %%
dfff3=data2['BSP']
dfff3.std(axis=0)
dfff3.mean(axis=0)
# Out:
# 17.690217391304348

# %%
dfff4=data2['KAJP']
dfff4.std(axis=0)
dfff4.mean(axis=0)
# Out:
# 2.4130434782608696

# %%
dfff5=data2['HJCPV']
dfff5.std(axis=0)
dfff5.mean(axis=0)
# Out:
# 6.114130434782608

# %%
dfff[dfff>274.33152173913044].count()
# Out:
# 97

# %%
dfff1[dfff1>246.1413043478261].count()
# Out:
# 90

# %%
dfff2[dfff2>47.25].count()
# Out:
# 59

# %%
dfff3[dfff3>17.690217391304348].count()
# Out:
# 44

# %%
dfff5[dfff5>6.114130434782608].count()
# Out:
# 49

# %%
labels = 'Above Mean', 'Below Mean'
fracs = [97, 87]
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('INC(2014)')
# Out:
# Text(0.5,1,'INC(2014)')

# %%
labels = 'Above Mean', 'Below Mean'
fracs = [90, 94]
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('INLD(2014)')
# Out:
# Text(0.5,1,'INLD(2014)')

# %%
labels = 'Above Mean', 'Below Mean'
fracs = [59, 125]
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('BJP(2014)')
# Out:
# Text(0.5,1,'BJP(2014)')

# %%
labels = 'Above Mean', 'Below Mean'
fracs = [44, 140]
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('BSP(2014)')
# Out:
# Text(0.5,1,'BSP(2014)')

# %%
labels = 'Above Mean', 'Below Mean'
fracs = [49, 135]
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('HJCPV(2014)')
# Out:
# Text(0.5,1,'HJCPV(2014)')

# %%
data1=pd.read_csv('/home/vivek/Documents/Internship/AAP_Data_Analytics/Task 6/Part 2/baroda/2005_VOTE%.csv')
data1.index = np.arange(1, len(data1)+1)
data1.drop(['Sr. No.'], axis = 1,inplace=True)
data1.tail()
# Out:
#          bjp %     inld %      es %      inc %     bsp %    other %
# 119   2.759527  28.777924  0.394218  53.219448  1.182654  13.666229
# 120   6.859593  29.260450  0.857449  33.869239  1.178992  27.974277
# 121   2.832244  40.631808  0.217865  46.840959  0.762527   8.714597
# 122  13.980263  44.901316  0.164474  27.138158  0.986842  12.828947
# 123   7.086614  29.133858  0.590551  35.039370  0.393701  27.755906

# %%
dt=data1.idxmax(axis=1)
count=0
count1=0
count2=0
count3=0
count4=0
count5=0
for i in range(len(dt)):
    if dt[i+1]=='inc %':
        count=count+1
    elif dt[i+1]=='inld %':
        count1=count1+1
    elif dt[i+1]=='bjp %':
        count2=count2+1
    elif dt[i+1]=='es %':
        count3=count3+1
    elif dt[i+1]=='bsp %':
        count4=count4+1
    elif dt[i+1]=='others %':
        count5=count5+1
print(count)
print(count1)
print(count2)
print(count3)
print(count4)
print(count5)
# Out:
# 42
# 47
# 13
# 2
# 1
# 0

# %%
labels = ['INC','INLD','BJP','ES','BSP','OTHERS']
fracs = [42,
47,
13,
2,
1,
0]
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('% of booths win, Baorda(2005)  ',fontsize=20)
# Out:
# Text(0.5,1,'% of booths win, Baorda(2005)  ')

# %%
x=data1['es %']
plt.figure(figsize=(20,50))
plt.xlabel('Vote Percentage',fontsize=20)
plt.ylabel('Booth Number',fontsize=20)
plt.title('ES',fontsize=20)
plt.tick_params(labelsize=15)
x.plot(kind='barh')

# %%
x=data1['inld %']
plt.figure(figsize=(20,50))
plt.xlabel('Vote Percentage',fontsize=20)
plt.ylabel('Booth Number',fontsize=20)
plt.title('INLD 2005',fontsize=20)
plt.tick_params(labelsize=15)
x.plot(kind='barh')

# %%
x=data1['bjp %']
plt.figure(figsize=(20,50))
plt.xlabel('Vote Percentage',fontsize=20)
plt.ylabel('Booth Number',fontsize=20)
plt.title('BJP 2005',fontsize=20)
plt.tick_params(labelsize=15)
x.plot(kind='barh')

# %%
x=data1['inc %']
plt.figure(figsize=(20,50))
plt.xlabel('Vote Percentage',fontsize=20)
plt.ylabel('Booth Number',fontsize=20)
plt.title('INC 2005',fontsize=20)
plt.tick_params(labelsize=15)
x.plot(kind='barh')

# %%
x=data1['bsp %']
plt.figure(figsize=(20,50))
plt.xlabel('Vote Percentage',fontsize=20)
plt.ylabel('Booth Number',fontsize=20)
plt.title('BSP 2005',fontsize=20)
plt.tick_params(labelsize=15)
x.plot(kind='barh')

# %%
data2=pd.read_csv('/home/vivek/Documents/Internship/AAP_Data_Analytics/Task 6/Part 2/baroda/2009_VOTE%.csv')
data2.index = np.arange(1, len(data1)+46)
data2.drop(['Sr. No.'], axis = 1,inplace=True)
data2.tail()
# Out:
#         bjp %     inld %     ncp %      inc %     bsp %   other %
# 164  0.000000  52.325581  0.000000  38.372093  9.302326  0.000000
# 165  1.798064  19.917012  0.138313  76.486860  0.138313  1.521438
# 166  0.631912  19.431280  0.157978  74.723539  0.000000  5.055292
# 167  0.000000  32.608696  2.173913  55.797101  7.246377  2.173913
# 168  1.176471  14.117647  0.168067  81.512605  0.336134  2.689076

# %%
dt1=data2.idxmax(axis=1)
count=0
count1=0
count2=0
count3=0
count4=0
count5=0
for i in range(len(dt1)):
    if dt1[i+1]=='inc %':
        count=count+1
    elif dt1[i+1]=='inld %':
        count1=count1+1
    elif dt1[i+1]=='bjp %':
        count2=count2+1
    elif dt1[i+1]=='ncp %':
        count3=count3+1
    elif dt1[i+1]=='bsp %':
        count4=count4+1
    elif dt1[i+1]=='other %':
        count5=count5+1
print(count)
print(count1)
print(count2)
print(count3)
print(count4)
print(count5)
# Out:
# 124
# 42
# 0
# 1
# 1
# 0

# %%
labels = ['INC','INLD','BJP','NCP','BSP','OTHERS']
fracs = [124,
42,
0,
1,
1,
0]
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('% of booths win, Baorda(2009)  ',fontsize=20)
# Out:
# Text(0.5,1,'% of booths win, Baorda(2009)  ')

# %%
x=data2['ncp %']
plt.figure(figsize=(20,50))
plt.xlabel('Vote Percentage',fontsize=20)
plt.ylabel('Booth Number',fontsize=20)
plt.title('NCP 2009',fontsize=20)
plt.tick_params(labelsize=15)
x.plot(kind='barh')

# %%
x=data2['bsp %']
plt.figure(figsize=(20,50))
plt.xlabel('Vote Percentage',fontsize=20)
plt.ylabel('Booth Number',fontsize=20)
plt.title('BSP 2009',fontsize=20)
plt.tick_params(labelsize=15)
x.plot(kind='barh')

# %%
x=data2['inc %']
plt.figure(figsize=(20,50))
plt.xlabel('Vote Percentage',fontsize=20)
plt.ylabel('Booth Number',fontsize=20)
plt.title('INC 2009',fontsize=20)
plt.tick_params(labelsize=15)
x.plot(kind='barh')

# %%
x=data2['inld %']
plt.figure(figsize=(20,50))
plt.xlabel('Vote Percentage',fontsize=20)
plt.ylabel('Booth Number',fontsize=20)
plt.title('INLD 2009',fontsize=20)
plt.tick_params(labelsize=15)
x.plot(kind='barh')

# %%
x=data2['bjp %']
plt.figure(figsize=(20,50))
plt.xlabel('Vote Percentage',fontsize=20)
plt.ylabel('Booth Number',fontsize=20)
plt.title('BJP 2009',fontsize=20)
plt.tick_params(labelsize=15)
x.plot(kind='barh')

# %%
data3=pd.read_csv('/home/vivek/Documents/Internship/AAP_Data_Analytics/Task 6/Part 2/baroda/2014_VOTE%.csv')
data3.index = np.arange(1, len(data1)+62)
data3.drop(['Sr. No.'], axis = 1,inplace=True)
data3.tail()
# Out:
#          bjp %     inld %   hcjpv %      inc %     bsp %   other %
# 180   5.084746  58.474576  0.000000  31.355932  5.084746  0.000000
# 181  18.949045  32.006369  0.000000  46.815287  0.159236  2.070064
# 182   2.820212  38.190364  0.000000  57.109283  0.117509  1.762632
# 183   6.818182  36.931818  0.568182  49.431818  1.704545  4.545455
# 184   4.694836  33.802817  0.117371  57.511737  0.469484  3.403756

# %%
dt2=data3.idxmax(axis=1)
count=0
count1=0
count2=0
count3=0
count4=0
count5=0
for i in range(len(dt2)):
    if dt2[i+1]=='inc %':
        count=count+1
    elif dt2[i+1]=='inld %':
        count1=count1+1
    elif dt2[i+1]=='bjp %':
        count2=count2+1
    elif dt2[i+1]=='hcj(bl) %':
        count3=count3+1
    elif dt2[i+1]=='bsp %':
        count4=count4+1
    elif dt2[i+1]=='other %':
        count5=count5+1
print(count)
print(count1)
print(count2)
print(count3)
print(count4)
print(count5)
# Out:
# 96
# 71
# 3
# 0
# 4
# 10

# %%
labels = ['INC','INLD','BJP','HCJ(bl)','BSP','OTHERS']
fracs = [96,
71,
3,
0,
4,
10]
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title('% of booths win, Baorda(2014)  ',fontsize=20)
# Out:
# Text(0.5,1,'% of booths win, Baorda(2014)  ')

# %%
x=data3['bjp %']
plt.figure(figsize=(20,50))
plt.xlabel('Vote Percentage',fontsize=20)
plt.ylabel('Booth Number',fontsize=20)
plt.title('BJP 2014',fontsize=20)
plt.tick_params(labelsize=15)
x.plot(kind='barh')

# %%
x=data3['inld %']
plt.figure(figsize=(20,50))
plt.xlabel('Vote Percentage',fontsize=20)
plt.ylabel('Booth Number',fontsize=20)
plt.title('INLD 2014',fontsize=20)
plt.tick_params(labelsize=15)
x.plot(kind='barh')

# %%
x=data3['inc %']
plt.figure(figsize=(20,50))
plt.xlabel('Vote Percentage',fontsize=20)
plt.ylabel('Booth Number',fontsize=20)
plt.title('INC 2014',fontsize=20)
plt.tick_params(labelsize=15)
x.plot(kind='barh')

# %%
x=data3['bsp %']
plt.figure(figsize=(20,50))
plt.xlabel('Vote Percentage',fontsize=20)
plt.ylabel('Booth Number',fontsize=20)
plt.title('BSP 2014',fontsize=20)
plt.tick_params(labelsize=15)
x.plot(kind='barh')

# %%
x=data3['hcjpv %']
plt.figure(figsize=(20,50))
plt.xlabel('Vote Percentage',fontsize=20)
plt.ylabel('Booth Number',fontsize=20)
plt.title('HCJPV 2014',fontsize=20)
plt.tick_params(labelsize=15)
x.plot(kind='barh')

# %%
x=[2005,2009,2014]
y=[13,0,3]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('% of booths win by BJP',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(3)
plt.xticks(x, ('2005','2009','2014'))
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
x=[2005,2009,2014]
y=[42,124,96]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('% of booths win by INC',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(3)
plt.xticks(x, ('2005','2009','2014'))
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
x=[2005,2009,2014]
y=[47,42,71]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('% of booths win by INLD',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(3)
plt.xticks(x, ('2005','2009','2014'))
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
x=[2005,2009,2014]
y=[1,1,4]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('% of booths win by BSP',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(3)
plt.xticks(x, ('2005','2009','2014'))
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
x=[2005,2009,2014]
y=[0,0,10]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('% of booths win by OTHERS',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(3)
plt.xticks(x, ('2005','2009','2014'))
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
x=[2005,2009,2014]
y=[2,0,0]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('% of booths win by ES',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(3)
plt.xticks(x, ('2005','2009','2014'))
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
x=[2005,2009,2014]
y=[0,1,0]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('% of booths win by NCP',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(3)
plt.xticks(x, ('2005','2009','2014'))
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
x=[2005,2009,2014]
y=[0,0,1]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('% of booths win by HCJ(BL)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(3)
plt.xticks(x, ('2005','2009','2014'))
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
x=[1,2]
y=[34.87844152,44.76190476]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('INLD (2005)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(2)
plt.xticks(x, ('% of vote share','% of winning booths'))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x=[5,10]
y=[1.205026001,0.9523809524]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('BSP (2005)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(2)
plt.xticks(x, ('% of vote share','% of winning booths'))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x=[5,10]
y=[30.61927514,40]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('INC (2005)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(2)
plt.xticks(x, ('% of vote share','% of winning booths'))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x=[5,10]
y=[16.62091175,12.38095238]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('BJP (2005)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(2)
plt.xticks(x, ('% of vote share','% of winning booths'))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x=[5,10]
y=[2.007496766,1.904761905]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('ES (2005)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(2)
plt.xticks(x, ('% of vote share','% of winning booths'))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x=[1,2]
y=[32.60759387,25]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('INLD (2009)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(2)
plt.xticks(x, ('% of vote share','% of winning booths'))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x=[5,10]
y=[2.605904464,0.5952380952]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('BSP (2009)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(2)
plt.xticks(x, ('% of vote share','% of winning booths'))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x=[5,10]
y=[59.36668497,73.80952381]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('INC (2009)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(2)
plt.xticks(x, ('% of vote share','% of winning booths'))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x=[5,10]
y=[1.245934874,0]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('BJP (2009)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(2)
plt.xticks(x, ('% of vote share','% of winning booths'))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x=[5,10]
y=[0.5680618322,0.5952380952]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('NCP (2009)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(2)
plt.xticks(x, ('% of vote share','% of winning booths'))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x=[1,2]
y=[37.74167506,38.58695652]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('INLD (2014)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(2)
plt.xticks(x, ('% of vote share','% of winning booths'))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x=[5,10]
y=[2.70909106,2.173913043]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('BSP (2014)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(2)
plt.xticks(x, ('% of vote share','% of winning booths'))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x=[5,10]
y=[42.0554136,52.17391304]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('INC (2014)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(2)
plt.xticks(x, ('% of vote share','% of winning booths'))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x=[5,10]
y=[7.239223976,1.630434783]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('BJP (2014)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(2)
plt.xticks(x, ('% of vote share','% of winning booths'))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x=[5,10]
y=[0.9371540811,0]
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('Year',fontsize=20)
#plt.ylabel('Booth Winning Percentage',fontsize=20)
plt.title('HJCPV (2014)',fontsize=20)
plt.tick_params(labelsize=15)
x = np.arange(2)
plt.xticks(x, ('% of vote share','% of winning booths'))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>
