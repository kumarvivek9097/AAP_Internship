# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/home/vivek/Downloads/julana_margin - Sheet1.csv')
data.head()
# Out:
#    year     margin
# 0  2014  18.319244
# 1  2014   7.685048
# 2  2014   8.273909
# 3  2014   8.890197
# 4  2014   0.327504

# %%
df1=data.loc[(data['year']==2014)]
df2=df1['margin']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('',fontsize=20)
plt.ylabel('Votes Percentage Margin',fontsize=20)
plt.title('2014 (Julana)',fontsize=20)
plt.tick_params(labelsize=15)
df2.plot(kind='bar')
x = np.arange(6)
plt.xticks(x, ('1','2','3','4','5','6'))
plt.show()

# %%
df1=data.loc[(data['year']==2009)]
df2=df1['margin']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('',fontsize=20)
plt.ylabel('Votes Percentage Margin',fontsize=20)
plt.title('2009 (Julana)',fontsize=20)
plt.tick_params(labelsize=15)
df2.plot(kind='bar')
x = np.arange(6)
plt.xticks(x, ('1','2','3','4','5','6'))
plt.show()

# %%
df1=data.loc[(data['year']==2005)]
df2=df1['margin']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('',fontsize=20)
plt.ylabel('Votes Percentage Margin',fontsize=20)
plt.title('2005 (Julana)',fontsize=20)
plt.tick_params(labelsize=15)
df2.plot(kind='bar')
x = np.arange(6)
plt.xticks(x, ('1','2','3','4','5','6'))
plt.show()

# %%
df1=data.loc[(data['year']==2000)]
df2=df1['margin']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('',fontsize=20)
plt.ylabel('Votes Percentage Margin',fontsize=20)
plt.title('2000 (Julana)',fontsize=20)
plt.tick_params(labelsize=15)
df2.plot(kind='bar')
x = np.arange(6)
plt.xticks(x, ('1','2','3','4','5','6'))
plt.show()

# %%
df1=data.loc[(data['year']==1996)]
df2=df1['margin']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('',fontsize=20)
plt.ylabel('Votes Percentage Margin',fontsize=20)
plt.title('1996 (Julana)',fontsize=20)
plt.tick_params(labelsize=15)
df2.plot(kind='bar')
x = np.arange(6)
plt.xticks(x, ('1','2','3','4','5','6'))
plt.show()
