# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/home/vivek/Downloads/Gohana_margin - Sheet1.csv')
data.head()
# Out:
#    Year     Margin
# 0  2014   2.755912
# 1  2014   8.366772
# 2  2014  22.322206
# 3  2014   0.449927
# 4  2014   0.040980

# %%
df1=data.loc[(data['Year']==2014)]
df2=df1['Margin']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
plt.xlabel('Position',fontsize=20)
plt.ylabel('Votes Percentage Margin',fontsize=20)
plt.title('2014 (Gohana)',fontsize=20)
plt.tick_params(labelsize=15)
df2.plot(kind='bar')
x = np.arange(6)
plt.xticks(x, ('1','2','3','4','5','6'))
plt.show()
#plt.bar(df2)

# %%
df1=data.loc[(data['Year']==2009)]
df2=df1['Margin']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('',fontsize=20)
plt.ylabel('Votes Percentage Margin',fontsize=20)
plt.title('2009 (Gohana)',fontsize=20)
plt.tick_params(labelsize=15)
df2.plot(kind='bar')
x = np.arange(6)
plt.xticks(x, ('1','2','3','4','5','6'))
plt.show()

# %%
df1=data.loc[(data['Year']==2005)]
df2=df1['Margin']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('',fontsize=20)
plt.ylabel('Votes Percentage Margin',fontsize=20)
plt.title('2005 (Gohana)',fontsize=20)
plt.tick_params(labelsize=15)
df2.plot(kind='bar')
x = np.arange(6)
plt.xticks(x, ('1','2','3','4','5','6'))
plt.show()

# %%
df1=data.loc[(data['Year']==2000)]
df2=df1['Margin']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('',fontsize=20)
plt.ylabel('Votes Percentage Margin',fontsize=20)
plt.title('2000 (Gohana)',fontsize=20)
plt.tick_params(labelsize=15)
df2.plot(kind='bar')
x = np.arange(6)
plt.xticks(x, ('1','2','3','4','5','6'))
plt.show()

# %%
df1=data.loc[(data['Year']==1996)]
df2=df1['Margin']
plt.figure(figsize=(20,10))
plt.grid(True, zorder=5)
#plt.xlabel('',fontsize=20)
plt.ylabel('Votes Percentage Margin',fontsize=20)
plt.title('1996 (Gohana)',fontsize=20)
plt.tick_params(labelsize=15)
df2.plot(kind='bar')
x = np.arange(5)
plt.xticks(x, ('1','2','3','4','5'))
plt.show()
